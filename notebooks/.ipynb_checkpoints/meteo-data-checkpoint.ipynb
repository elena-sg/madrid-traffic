# %%
import pandas as pd
import numpy as np
from graph_traffic.config import data_path

import matplotlib as mpl
import os

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %% [markdown]
# ## Localizaciones

# %%
locs = pd.read_csv(f'{data_path}/01-raw/meteo/Estaciones_control_datos_meteorologicos.csv', sep=';', encoding="cp1252", usecols=['CÓDIGO_CORTO', 'LONGITUD', 'LATITUD'])\
    .dropna(subset=['CÓDIGO_CORTO'])
locs.columns = ['codigo_corto', 'longitud', 'latitud']
locs.head()
# Out:
#    codigo_corto  longitud    latitud
# 0           4.0 -3.712257  40.423882
# 1           8.0 -3.682316  40.421553
# 2          16.0 -3.639242  40.440046
# 3          18.0 -3.731836  40.394782
# 4          24.0 -3.747345  40.419358

# %%
locs.to_csv('files/estaciones_proc.csv', index=False)

# %%
cods_cortos = sorted(locs.codigo_corto.values)

# %% [markdown]
# ## Datos meteo

# %%
hcols = [f"H{d:02}" for d in range(1, 25)]
vcols = [f"V{d:02}" for d in range(1, 25)]

# %%
files20 = [f'files/2020-meteo/{file}' for file in os.listdir('files/2020-meteo')]
files21 = [f'files/2021-meteo/{file}' for file in os.listdir('files/2021-meteo')]
for file in files20 + files21:
    df = pd.read_csv(file, sep=';')
    df['fecha'] = pd.to_datetime(dict(year=df.ANO, month=df.MES, day=df.DIA))
    magnitudes = {
        80: 'radiacion_ultravioleta',
        81: 'velocidad_viento',
        82: 'dir_viento',
        83: 'temperatura',
        86: 'humedad_relativa',
        87: 'presion_barometrica',
        88: 'radiacion_solar',
        89: 'precipitacion'
    }
    df['magnitud'] = df.MAGNITUD.apply(lambda x: magnitudes[x])
    del df['PROVINCIA'], df['MUNICIPIO'], df['PUNTO_MUESTREO'], df['ANO'], df['MES'], df['DIA'], df['MAGNITUD']
    df = df.rename(columns={'ESTACION': 'estacion'})
    fechas = sorted(df.fecha.unique())

    magnitudes = ['velocidad_viento', 'dir_viento', 'temperatura', 'humedad_relativa', 'presion_barometrica', 'radiacion_solar', 'precipitacion']
    magnitudes_x = [f'{m}_x' for m in magnitudes]
    magnitudes_y = [f'{m}_y' for m in magnitudes]
    dfn = pd.DataFrame([], columns=['estacion', 'fecha', 'hora'] + magnitudes_x + magnitudes_y)

    for estacion in cods_cortos:
        for fecha in fechas:
            dff = df[(df.fecha==fecha) & (df.estacion==estacion)]

            dfh = dff[['magnitud']+hcols].set_index('magnitud').transpose()
            dfh['hora'] = dfh.index.to_series().apply(lambda x: int(x[1:]))

            dfv = dff[['magnitud']+vcols].set_index('magnitud').transpose()
            dfv['hora'] = dfv.index.to_series().apply(lambda x: int(x[1:]))

            dfm = dfh.merge(dfv, on='hora')
            dfm['estacion'] = estacion
            dfm['fecha'] = fecha

            dfn = dfn.append(dfm)

    dfn[magnitudes_x] = np.where(dfn[magnitudes_y]=='V', dfn[magnitudes_x], np.nan)
    dfn = dfn.rename(columns=dict(zip(magnitudes_x, magnitudes)))
    for m in magnitudes_y:
        del dfn[m]

    dfn.loc[dfn.hora==24, 'fecha'] = dfn.loc[dfn.hora==24, 'fecha'] + pd.DateOffset(days=1)
    dfn.loc[dfn.hora==24, 'hora'] = 0
    dfn['hora'] = dfn.hora.apply(lambda x: f'{x:02}:00:00')
    dfn.fecha = pd.to_datetime(dfn.fecha.astype(str) + " " + dfn.hora)
    del dfn['hora']
    dfn.to_csv(f'files/procesados/por_mes/{file.split("/")[-1]}', index=False)

# %%
def transform_df(df):
    df.loc[df.temperatura<-25] = np.nan
    df.loc[df.humedad_relativa<0] = np.nan

    wv = df.pop('velocidad_viento')
    wd_rad = df.pop('dir_viento')*np.pi / 180
    df['vientox'] = wv*np.cos(wd_rad)
    df['vientoy'] = wv*np.sin(wd_rad)
    
    return df

# %%
df20 = pd.DataFrame([])
df21 = pd.DataFrame([])
for file in sorted(os.listdir('files/procesados/por_mes')):
    path = 'files/procesados/por_mes/' + file
    if file.endswith('20.csv'):
        df20 = df20.append(pd.read_csv(path))
    elif file.endswith('21.csv'):
        df21 = df21.append(pd.read_csv(path))
df20 = df20.sort_values('fecha')
df21 = df21.sort_values('fecha')

df20 = transform_df(df20)
df21 = transform_df(df21)

df = pd.concat([df20, df21], ignore_index=True).sort_values('fecha').dropna(subset=['estacion'])

estaciones = set(df.estacion.unique())

for est in estaciones:
    df[df.estacion==est].to_csv(f'files/procesados/anual/estacion-{est:.0f}.csv', index=False)

# %%
df = df[df.estacion==est].reset_index(drop=True)

# %%
df
# Out:
#        estacion                fecha  temperatura  humedad_relativa  \
# 0         115.0  2020-01-01 01:00:00          3.1              91.0
# 1         115.0  2020-01-01 02:00:00          2.5              91.0
# 2         115.0  2020-01-01 03:00:00          2.1              91.0
# 3         115.0  2020-01-01 04:00:00          1.7              90.0
# 4         115.0  2020-01-01 05:00:00          1.3              91.0
# ...         ...                  ...          ...               ...
# 17539     115.0  2021-12-31 20:00:00         11.4              79.0
# 17540     115.0  2021-12-31 21:00:00          9.8              81.0
# 17541     115.0  2021-12-31 22:00:00          8.7              83.0
# 17542     115.0  2021-12-31 23:00:00          7.6              86.0
# 17543     115.0  2022-01-01 00:00:00          6.7              87.0
#
#        presion_barometrica  radiacion_solar  precipitacion  vientox  vientoy
# 0                      NaN              NaN            NaN      NaN      NaN
# 1                      NaN              NaN            NaN      NaN      NaN
# 2                      NaN              NaN            NaN      NaN      NaN
# 3                      NaN              NaN            NaN      NaN      NaN
# 4                      NaN              NaN            NaN      NaN      NaN
# ...                    ...              ...            ...      ...      ...
# 17539                  NaN              NaN            NaN      NaN      NaN
# 17540                  NaN              NaN            NaN      NaN      NaN
# 17541                  NaN              NaN            NaN      NaN      NaN
# 17542                  NaN              NaN            NaN      NaN      NaN
# 17543                  NaN              NaN            NaN      NaN      NaN
#
# [17544 rows x 9 columns]

# %%
df = pd.concat([pd.read_csv(f'files/procesados/anual/{e}') for e in os.listdir('files/procesados/anual/')])
meteo_magn = ['temperatura', 'humedad_relativa', 'presion_barometrica',
              'radiacion_solar', 'precipitacion', 'vientox', 'vientoy']
for m in meteo_magn:
    df[f'period_no_change_{m}'] = df[m].groupby(
        ((df[m] != df[m].shift())).cumsum()
    ).transform('size')
pd.concat([
    df[f'period_no_change_{m}'].value_counts(normalize=True).sort_index().cumsum() for m in meteo_magn
], axis=1).head(30)
# Out:
#     period_no_change_temperatura  period_no_change_humedad_relativa  \
# 1                       0.939790                           0.822970
# 2                       0.990643                           0.942131
# 3                       0.997878                           0.975977
# 4                       0.999132                           0.986570
# 5                       0.999406                           0.990461
# 6                       0.999458                           0.992250
# 7                       0.999474                           0.993156
# 8                            NaN                           0.993769
# 9                            NaN                           0.994243
# 10                           NaN                           0.994835
# 11                           NaN                           0.995317
# 12                           NaN                           0.995686
# 13                           NaN                           0.996056
# 14                           NaN                           0.996547
# 15                           NaN                           0.996975
# 16                           NaN                           0.997220
# 17                           NaN                           0.997295
# 18                           NaN                           0.997492
# 19                           NaN                           0.997700
# 20                           NaN                           0.997919
# 21                           NaN                           0.998012
# 22                           NaN                                NaN
# 23                           NaN                           0.998112
# 24                           NaN                                NaN
# 25                           NaN                                NaN
# 26                           NaN                                NaN
# 27                           NaN                           0.998172
# 28                           NaN                                NaN
# 29                           NaN                                NaN
# 30                           NaN                           0.998237
#
#     period_no_change_presion_barometrica  period_no_change_radiacion_solar  \
# 1                               0.727812                          0.863291
# 2                               0.767927                          0.867141
# 3                               0.806902                          0.869495
# 4                               0.839963                          0.871714
# 5                               0.870063                          0.873643
# 6                               0.895845                          0.875787
# 7                               0.916654                          0.877767
# 8                               0.934368                          0.888080
# 9                               0.947924                          0.903529
# 10                              0.960858                          0.924575
# 11                              0.970480                          0.935789
# 12                              0.977847                          0.956230
# 13                              0.984031                          0.971107
# 14                              0.988021                          0.998546
# 15                              0.991112                          0.999928
# 16                              0.993954                          0.999963
# 17                              0.995854                          1.000000
# 18                              0.996920                               NaN
# 19                              0.997919                               NaN
# 20                              0.998577                               NaN
# 21                              0.998945                               NaN
# 22                              0.999138                               NaN
# 23                              0.999491                               NaN
# 24                              0.999544                               NaN
# 25                              0.999599                               NaN
# 26                                   NaN                               NaN
# 27                                   NaN                               NaN
# 28                                   NaN                               NaN
# 29                                   NaN                               NaN
# 30                                   NaN                               NaN
#
#     period_no_change_precipitacion  period_no_change_vientox  \
# 1                         0.647531                  0.995716
# 2                         0.650995                  0.997470
# 3                         0.653034                  0.998049
# 4                         0.654595                  0.998557
# 5                         0.656184                  0.998766
# 6                         0.657618                  0.998937
# 7                         0.659168                  0.999167
# 8                         0.660764                  0.999395
# 9                         0.662205                  0.999494
# 10                        0.663630                       NaN
# 11                        0.664811                  0.999518
# 12                        0.666416                  0.999570
# 13                        0.667756                  0.999599
# 14                        0.668891                  0.999629
# 15                        0.670239                       NaN
# 16                        0.671713                       NaN
# 17                        0.673054                  0.999704
# 18                        0.674120                  0.999743
# 19                        0.675369                       NaN
# 20                        0.677079                       NaN
# 21                        0.678092                  0.999790
# 22                        0.679443                  0.999838
# 23                        0.681006                       NaN
# 24                        0.682163                  0.999890
# 25                        0.683095                  1.000000
# 26                        0.684235                       NaN
# 27                        0.685182                       NaN
# 28                        0.686349                       NaN
# 29                        0.687493                       NaN
# 30                        0.688545                       NaN
#
#     period_no_change_vientoy
# 1                   0.995008
# 2                   0.997165
# 3                   0.997862
# 4                   0.998380
# 5                   0.998599
# 6                   0.998770
# 7                   0.999000
# 8                   0.999228
# 9                   0.999327
# 10                       NaN
# 11                       NaN
# 12                  0.999406
# 13                  0.999434
# 14                  0.999465
# 15                       NaN
# 16                       NaN
# 17                  0.999540
# 18                  0.999579
# 19                       NaN
# 20                       NaN
# 21                  0.999625
# 22                  0.999673
# 23                       NaN
# 24                  0.999726
# 25                  0.999836
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# 30                       NaN

# %%
import pandas as pd
import os

# %%
path = "../processed/meteo/files_per_station/"
mdict = dict()
mmagns = ['temperatura', 'humedad_relativa', 'presion_barometrica',
              'radiacion_solar', 'precipitacion', 'vientox', 'vientoy']
for file in os.listdir(path):
    df = pd.read_csv(path + file)
    notnull = df[mmagns].notna().any()
    estacion = int(file.split('-')[1].split(".")[0])
    mdict[estacion] = notnull.to_dict()

# %%
locs.set_index('codigo_corto').merge(pd.DataFrame(mdict).transpose(), left_index=True, right_index=True).to_csv('files/estaciones_proc.csv', index_label='estacion')

# %%
locs.set_index('codigo_corto').merge(pd.DataFrame(mdict).transpose(), left_index=True, right_index=True).
# Out:
#        longitud    latitud  temperatura  humedad_relativa  \
# 4.0   -3.712257  40.423882         True             False
# 8.0   -3.682316  40.421553         True              True
# 16.0  -3.639242  40.440046        False              True
# 18.0  -3.731836  40.394782         True             False
# 24.0  -3.747345  40.419358         True              True
# 35.0  -3.703166  40.419209         True              True
# 36.0  -3.645310  40.407952         True              True
# 38.0  -3.707130  40.445544         True              True
# 39.0  -3.711536  40.478232        False              True
# 54.0  -3.612139  40.373012         True              True
# 56.0  -3.718768  40.385034         True              True
# 58.0  -3.774610  40.518070         True              True
# 59.0  -3.616341  40.460726         True              True
# 102.0 -3.635637  40.399793         True              True
# 103.0 -3.709525  40.350628         True              True
# 104.0 -3.679722  40.365833        False             False
# 106.0 -3.740000  40.442222         True              True
# 107.0 -3.656667  40.462778         True              True
# 108.0 -3.717881  40.476633         True              True
# 109.0 -3.696950  40.431911         True              True
# 110.0 -3.710792  40.415600         True              True
# 111.0 -3.680369  40.422649         True              True
# 112.0 -3.666456  40.396472         True              True
# 113.0 -3.666456  40.396472         True              True
# 114.0 -3.697631  40.392544         True              True
# 115.0 -3.697631  40.392544         True              True
#
#        presion_barometrica  radiacion_solar  precipitacion  vientox  vientoy
# 4.0                  False            False          False    False    False
# 8.0                  False            False          False    False    False
# 16.0                 False            False          False    False    False
# 18.0                 False            False          False    False    False
# 24.0                  True             True           True     True     True
# 35.0                 False            False          False    False    False
# 36.0                 False            False          False    False    False
# 38.0                 False            False          False    False    False
# 39.0                 False            False           True    False    False
# 54.0                 False             True           True     True     True
# 56.0                  True            False           True     True     True
# 58.0                 False            False          False    False    False
# 59.0                  True             True           True     True     True
# 102.0                 True             True           True     True     True
# 103.0                 True             True           True     True     True
# 104.0                False            False          False     True     True
# 106.0                 True             True           True     True     True
# 107.0                 True             True           True     True     True
# 108.0                 True             True           True     True     True
# 109.0                False            False          False    False    False
# 110.0                False            False          False    False    False
# 111.0                False            False          False    False    False
# 112.0                False            False          False    False    False
# 113.0                False            False          False    False    False
# 114.0                False            False          False    False    False
# 115.0                False            False          False    False    False

# %%
pd.DataFrame(mdict).transpose()
# Out:
#      temperatura  humedad_relativa  presion_barometrica  radiacion_solar  \
# 114         True              True                False            False
# 112         True              True                False            False
# 107         True              True                 True             True
# 8           True              True                False            False
# 58          True              True                False            False
# 103         True              True                 True             True
# 4           True             False                False            False
# 36          True              True                False            False
# 38          True              True                False            False
# 104        False             False                False            False
# 102         True              True                 True             True
# 56          True              True                 True            False
# 59          True              True                 True             True
# 18          True             False                False            False
# 113         True              True                False            False
# 110         True              True                False            False
# 108         True              True                 True             True
# 106         True              True                 True             True
# 109         True              True                False            False
# 35          True              True                False            False
# 115         True              True                False            False
# 54          True              True                False             True
# 111         True              True                False            False
# 24          True              True                 True             True
# 16         False              True                False            False
# 39         False              True                False            False
#
#      precipitacion  vientox  vientoy
# 114          False    False    False
# 112          False    False    False
# 107           True     True     True
# 8            False    False    False
# 58           False    False    False
# 103           True     True     True
# 4            False    False    False
# 36           False    False    False
# 38           False    False    False
# 104          False     True     True
# 102           True     True     True
# 56            True     True     True
# 59            True     True     True
# 18           False    False    False
# 113          False    False    False
# 110          False    False    False
# 108           True     True     True
# 106           True     True     True
# 109          False    False    False
# 35           False    False    False
# 115          False    False    False
# 54            True     True     True
# 111          False    False    False
# 24            True     True     True
# 16           False    False    False
# 39            True    False    False
